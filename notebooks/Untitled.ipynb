# %%
import asyncio
import sys

if sys.platform == "win32":
    asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

from typing import TypedDict, List, Annotated
import operator



class ResearchState(TypedDict):
    topic: str
    sources: Annotated[List[str], operator.add]
    draft: str
    revisions: int
    messages: Annotated[List[dict], operator.add]

# %%
from langchain_community.tools import DuckDuckGoSearchResults

def research_node(state: ResearchState):
    search = DuckDuckGoSearchResults(max_results=5)
    results = search.invoke(state["topic"])
    
        
    
    return {
        "sources": [results],
        "messages": [{
            "role": "researcher",
            "content": f"Found {len(results)} relevant sources"
        }]
    }

# %%
from pydantic import BaseModel
from config import config
import asyncio
from pydantic import BaseModel
from crawl4ai import AsyncWebCrawler, BrowserConfig, CrawlerRunConfig, CacheMode
from crawl4ai.extraction_strategy import LLMExtractionStrategy
from config import config

class ExtractedData(BaseModel):
    title: str
    url: str
    summary: str

max_tokens = (1024*8)
# Configure the LLM extraction strategy with OpenRouter
llm_strategy = LLMExtractionStrategy(
    provider="openrouter",
    api_token=config.OPENROUTER_API_KEY,
    schema=ExtractedData.model_json_schema(),
    extraction_type="schema",
    instruction="Extract the title, URL, and summary from the content.",
    chunk_token_threshold=1200,
    apply_chunking=True,
    input_format="html",
    extra_args={
        "model": "meta-llama/llama-3.2-3b-instruct",  # Specify the model to use
        "temperature": 0.1,
        "max_tokens": 1000,
    },
)

# %%
import requests
import json
import time

def crawl_with_openrouter(url: str, api_token: str = None):
    headers = {"Authorization": f"Bearer {api_token}"} if api_token else {}

    request_data = {
        "urls": url,
        "extraction_strategy": {
            "type": "llm",
            "provider": "openrouter",
            "model": "meta-llama/llama-3.2-3b-instruct",
            "instruction": "Extract the title, URL, and summary from the content.",
            "schema": {
                "title": "str",
                "url": "str",
                "summary": "str"
            }
        },
        "cache_mode": "bypass",
        "extra_args": {
            "temperature": 0.1,
            "max_tokens": 1000
        }
    }

    response = requests.post("http://localhost:11235/crawl", headers=headers, json=request_data)
    print(response.json())
    task_id = response.json().get("task_id")

    while True:
        result = requests.get(f"http://localhost:11235/task/{task_id}", headers=headers)
        status = result.json()

        if status["status"] == "completed":
            return status["result"]["extracted_content"]
        elif status["status"] == "failed":
            print("Crawl failed:", status["error"])
            return None

        time.sleep(2)

# Example usage
url = "https://www.lycamobile.co.uk/en/how-to/how-to-activate-my-new-sim-and-prepay-plan/?utm_source=onboarding&utm_medium=email&utm_campaign=freesimactivation"
api_token = "899839892"  # Replace with your actual token if needed
data = crawl_with_openrouter(url, api_token)
print(json.dumps(data, indent=2))
# Out:
# {'task_id': 'e2f04c8f-4139-4ed0-b795-f81da3d0e509'}
# null

# %%
from langchain_openai import ChatOpenAI
from config import config
def writer_node(state: ResearchState):
   
    
    llm = ChatOpenAI(
        model="meta-llama/llama-3.2-3b-instruct",
        openai_api_key=config.OPENROUTER_API_KEY,
        openai_api_base=config.OPENROUTER_API_BASE,
        max_retries=3,
        max_tokens=max_tokens
    ) 
    sources = "\n".join(state["sources"][-5:])
    
    response = llm.invoke(f"""
    Write a comprehensive report on: {state['topic']}
    Using these sources:
    {sources}
    """)
    
    return {
        "draft": response.content,
        "messages": [{
            "role": "writer", 
            "content": "Draft generated"
        }]
    }

# %%
from langgraph.graph import StateGraph, END

# Initialize graph
workflow = StateGraph(ResearchState)

# Add nodes
workflow.add_node("research", research_node)
workflow.add_node("write", writer_node)

# Set edges
workflow.set_entry_point("research")
workflow.add_edge("research", "write")
workflow.add_edge("write", END)

# Compile
chain = workflow.compile()

# %%
# Run with topic
result = chain.invoke({
    "topic": "Recent advances in AI protein folding",
    "sources": [],
    "draft": "",
    "revisions": 0,
    "messages": []
})

print(f"""
# Final Report: {result['topic']}
{result['draft']}


""")
# Out:
# # Final Report: Recent advances in AI protein folding
# **Comprehensive Report: Recent Advances in AI Protein Folding**
#
# **Introduction**
#
# The protein folding problem has been a long-standing challenge in biology, with proteins in their native state having unique three-dimensional structures that determine their function and interact with other molecules. Despite significant efforts, solving this problem remained elusive until the advent of artificial intelligence (AI) approaches. Recent advances in AI protein folding have revolutionized the field, enabling the prediction of protein structures with unprecedented accuracy and opening up new avenues for protein design and engineering.
#
# **Background**
#
# The protein folding problem involves predicting the three-dimensional structure of a protein from its amino acid sequence. This problem is difficult due to the vast number of possible conformations, known as conformational space, which contains millions of unique structures. The development of AI approaches to protein folding has been a multi-disciplinary effort, combining expertise from computer science, bioinformatics, and biophysics.
#
# **Recent Advances**
#
# Recent advances in AI protein folding have been marked by significant breakthroughs in accuracy and efficiency. The development of the AlphaFold algorithm, for example, has achieved remarkable success in predicting protein structures with high accuracy. AlphaFold uses a combination of machine learning and physics-based modeling to predict protein structures, and its performance has been consistently impressive in benchmarking experiments.
#
# **Key Developments**
#
# Several key developments have contributed to the recent advances in AI protein folding:
#
# 1. **AlphaFold**: The AlphaFold algorithm, developed by Google DeepMind, has achieved remarkable success in predicting protein structures with high accuracy. AlphaFold uses a combination of machine learning and physics-based modeling to predict protein structures, and its performance has been consistently impressive in benchmarking experiments.
# 2. **Machine Learning**: The use of machine learning algorithms has been a key driver of recent advances in AI protein folding. Machine learning algorithms can be trained on large datasets of protein structures and sequences to learn patterns and relationships that are not apparent to humans.
# 3. **Rosetta**: The Rosetta algorithm, developed by David Baker and colleagues, has been used to predict protein structures and design new proteins. Rosetta uses a combination of machine learning and physics-based modeling to predict protein structures and design new proteins.
# 4. **CASP**: The Critical Assessment of protein Structure Prediction (CASP) experiment has been a key benchmarking platform for evaluating protein structure prediction algorithms. CASP has provided a comprehensive framework for evaluating the performance of AI protein folding algorithms.
#
# **Impact and Applications**
#
# The recent advances in AI protein folding have significant implications for various fields, including:
#
# 1. **Protein Engineering**: AI protein folding algorithms can be used to design new proteins with specific functions or properties.
# 2. **Biotechnology**: AI protein folding algorithms can be used to predict protein structures and design new proteins for biotechnological applications, such as vaccine development and protein production.
# 3. **Disease Research**: AI protein folding algorithms can be used to predict protein structures and design new proteins for therapeutic applications, such as enzyme inhibitors and antibody design.
# 4. **Synthetic Biology**: AI protein folding algorithms can be used to design new proteins with specific functions or properties for synthetic biology applications.
#
# **Conclusion**
#
# The recent advances in AI protein folding have revolutionized the field of protein science, enabling the prediction of protein structures with unprecedented accuracy and opening up new avenues for protein design and engineering. The development of AI protein folding algorithms has significant implications for various fields, including protein engineering, biotechnology, disease research, and synthetic biology. As AI protein folding continues to evolve, it is likely to have a profound impact on our understanding of protein biology and its applications in various fields.
#
# **Recommendations**
#
# Based on the recent advances in AI protein folding, the following recommendations are made:
#
# 1. **Further Development of AI Protein Folding Algorithms**: Continued investment in the development of AI protein folding algorithms is necessary to improve their accuracy and efficiency.
# 2. **Integration of AI Protein Folding with Experimental Methods**: Integration of AI protein folding with experimental methods, such as X-ray crystallography and NMR spectroscopy, is necessary to validate the accuracy of predicted protein structures.
# 3. **Applications in Biotechnology and Synthetic Biology**: AI protein folding algorithms should be applied in biotechnology and synthetic biology to design new proteins with specific functions or properties.
# 4. **Training and Education**: Training and education programs should be established to educate researchers and students on the use of AI protein folding algorithms and their applications in protein science.
